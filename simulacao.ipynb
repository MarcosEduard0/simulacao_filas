# %%
pip install seaborn
# Out:
# Requirement already satisfied: seaborn in c:\users\thier\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (0.12.2)
# Requirement already satisfied: numpy!=1.24.0,>=1.17 in c:\users\thier\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from seaborn) (1.23.5)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.1 in c:\users\thier\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from seaborn) (3.7.1)
# Requirement already satisfied: pandas>=0.25 in c:\users\thier\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from seaborn) (1.5.1)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\thier\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (9.5.0)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\thier\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (2.8.2)
# Requirement already satisfied: packaging>=20.0 in c:\users\thier\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (21.3)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\thier\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (3.0.9)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\thier\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (4.39.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\thier\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (0.11.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\thier\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (1.4.4)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\thier\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (1.0.7)
# Requirement already satisfied: importlib-resources>=3.2.0 in c:\users\thier\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (5.12.0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\thier\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from pandas>=0.25->seaborn) (2022.6)
# Requirement already satisfied: zipp>=3.1.0 in c:\users\thier\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from importlib-resources>=3.2.0->matplotlib!=3.6.1,>=3.1->seaborn) (3.10.0)
# Requirement already satisfied: six>=1.5 in c:\users\thier\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.1->seaborn) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip available: 22.3.1 -> 23.1.2
# [notice] To update, run: C:\Users\thier\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %%
import numpy as np
import pandas as pd
import seaborn as sns

# %%
# num_samples = int(input("Digite o número de amostras: "))
# mean_arrival_time = float(input("Digite o tempo médio de chegada das amostras: "))
# mean_departure_time = float(input("Digite o tempo médio de saída das amostras: "))

num_samples = 120
mean_arrival_time = 1
mean_departure_time = 2

# %%
print("\nTempo de chegada | Tipo de evento | Número de amostras\n")

n = 0
simul_time = 0
data = []

# To calculate waiting line mean time
arrivals = []
waiting_line_time = 0

for i in range(num_samples):
    arrival_time = np.random.exponential(scale=1/mean_arrival_time)
    departure_time = np.random.exponential(scale=1/mean_departure_time)

    if n == 0 or arrival_time < departure_time:
        simul_time += arrival_time
        print(f"{simul_time:8.4f} \t\t{'Chegada':14} {n:2} => {n+1:2}")
        data.append([f"{simul_time:8.4f}", f"{'Chegada'}", f"{n}", f"{n+1}"])
        n += 1
        if (n > 1):
            arrivals.append(simul_time)
    else:
        simul_time += departure_time
        if (len(arrivals) > 0):
            waiting_line_time += simul_time - arrivals[0]
            arrivals.pop(0)
        print(f"{simul_time:8.4f} \t\t{'Saída':14} {n:2} => {n-1:2}")
        data.append([f"{simul_time:8.4f}", f"{'Saída'}", f"{n}", f"{n+1}"])
        n -= 1

print(f"\nTotal de pessoas que foram ao banco na simulação: {num_samples}")
print(f"Número de pessoas na fila ao final da simulação: {n}")
print(f"Tempo total da simulação: {simul_time:.4f}")
print(f"Tempo médio de espera na fila: {(waiting_line_time/num_samples):.4f}")
# Out:
# Tempo de chegada | Tipo de evento | Número de amostras
#
#   0.3520 		Chegada         0 =>  1
#   0.6766 		Chegada         1 =>  2
#   0.7148 		Chegada         2 =>  3
#   0.7575 		Saída           3 =>  2
#   1.3236 		Saída           2 =>  1
#   2.0446 		Saída           1 =>  0
#   2.0915 		Chegada         0 =>  1
#   2.6285 		Chegada         1 =>  2
#   2.7307 		Saída           2 =>  1
#   3.2976 		Saída           1 =>  0
#   3.8374 		Chegada         0 =>  1
#   4.3801 		Saída           1 =>  0
#   5.1576 		Chegada         0 =>  1
#   5.2702 		Chegada         1 =>  2
#   5.5800 		Chegada         2 =>  3
#   5.5990 		Chegada         3 =>  4
#   5.6012 		Chegada         4 =>  5
#   5.6543 		Chegada         5 =>  6
#   5.7347 		Saída           6 =>  5
#   5.8258 		Saída           5 =>  4
#   5.8735 		Saída           4 =>  3
#   6.9202 		Saída           3 =>  2
#   7.0791 		Saída           2 =>  1
#   7.2152 		Saída           1 =>  0
#   9.5380 		Chegada         0 =>  1
#   9.8442 		Saída           1 =>  0
#  10.1392 		Chegada         0 =>  1
#  10.2614 		Chegada         1 =>  2
#  10.8434 		Saída           2 =>  1
#  11.4798 		Saída           1 =>  0
#  11.6468 		Chegada         0 =>  1
#  12.5376 		Saída           1 =>  0
#  12.9358 		Chegada         0 =>  1
#  13.8134 		Chegada         1 =>  2
#  13.9620 		Saída           2 =>  1
#  14.0606 		Chegada         1 =>  2
#  14.3972 		Saída           2 =>  1
#  14.8998 		Saída           1 =>  0
#  15.9224 		Chegada         0 =>  1
#  15.9866 		Saída           1 =>  0
#  16.6083 		Chegada         0 =>  1
#  16.7681 		Saída           1 =>  0
#  17.1696 		Chegada         0 =>  1
#  17.2762 		Chegada         1 =>  2
#  18.3142 		Chegada         2 =>  3
#  18.4608 		Saída           3 =>  2
#  19.1736 		Saída           2 =>  1
#  19.4963 		Chegada         1 =>  2
#  19.6366 		Chegada         2 =>  3
#  19.6587 		Saída           3 =>  2
#  19.9216 		Saída           2 =>  1
#  20.7965 		Chegada         1 =>  2
#  21.0498 		Saída           2 =>  1
#  21.3905 		Saída           1 =>  0
#  22.1813 		Chegada         0 =>  1
#  22.2267 		Chegada         1 =>  2
#  22.9535 		Chegada         2 =>  3
#  23.2566 		Chegada         3 =>  4
#  23.8879 		Saída           4 =>  3
#  23.8894 		Saída           3 =>  2
#  24.9053 		Saída           2 =>  1
#  24.9538 		Chegada         1 =>  2
#  25.1120 		Saída           2 =>  1
#  27.0122 		Saída           1 =>  0
#  28.7220 		Chegada         0 =>  1
#  29.0103 		Saída           1 =>  0
#  29.0714 		Chegada         0 =>  1
#  29.2884 		Saída           1 =>  0
#  29.3137 		Chegada         0 =>  1
#  29.7642 		Chegada         1 =>  2
#  29.9243 		Chegada         2 =>  3
#  30.0662 		Saída           3 =>  2
#  30.6780 		Saída           2 =>  1
#  30.8283 		Saída           1 =>  0
#  33.9861 		Chegada         0 =>  1
#  34.1949 		Chegada         1 =>  2
#  34.3466 		Chegada         2 =>  3
#  34.5475 		Saída           3 =>  2
#  34.9032 		Saída           2 =>  1
#  35.3790 		Chegada         1 =>  2
#  35.7560 		Chegada         2 =>  3
#  35.7998 		Chegada         3 =>  4
#  35.9297 		Chegada         4 =>  5
#  36.0490 		Saída           5 =>  4
#  37.1779 		Chegada         4 =>  5
#  37.4434 		Saída           5 =>  4
#  37.5749 		Chegada         4 =>  5
#  37.6183 		Saída           5 =>  4
#  39.2720 		Chegada         4 =>  5
#  39.7405 		Saída           5 =>  4
#  40.1465 		Chegada         4 =>  5
#  40.3360 		Saída           5 =>  4
#  40.3942 		Saída           4 =>  3
#  40.4749 		Saída           3 =>  2
#  41.0540 		Chegada         2 =>  3
#  41.0728 		Saída           3 =>  2
#  41.2881 		Saída           2 =>  1
#  41.3828 		Saída           1 =>  0
#  41.7667 		Chegada         0 =>  1
#  41.8633 		Saída           1 =>  0
#  45.8168 		Chegada         0 =>  1
#  46.0080 		Saída           1 =>  0
#  46.8842 		Chegada         0 =>  1
#  47.1209 		Saída           1 =>  0
#  47.6091 		Chegada         0 =>  1
#  48.0316 		Chegada         1 =>  2
#  48.4048 		Saída           2 =>  1
#  48.8508 		Chegada         1 =>  2
#  49.2758 		Chegada         2 =>  3
#  49.4131 		Saída           3 =>  2
#  49.4642 		Chegada         2 =>  3
#  50.0249 		Saída           3 =>  2
#  50.0601 		Saída           2 =>  1
#  50.1586 		Saída           1 =>  0
#  51.0349 		Chegada         0 =>  1
#  51.1528 		Saída           1 =>  0
#  51.5907 		Chegada         0 =>  1
#  52.3675 		Saída           1 =>  0
#  53.3652 		Chegada         0 =>  1
#  53.9997 		Chegada         1 =>  2
# \Total de pessoas que foram ao banco na simulação: 120
#
# Número de pessoas na fila ao final da simulação: 2
# Tempo total da simulação: 53.9997
# Tempo médio de espera na fila: 0.2776

# %%
df = pd.DataFrame(data, columns=['Tempo de Chegada', 'Tipo de Evento', 'Antes', 'Depois'])
df
# Out:
#     Tempo de Chegada Tipo de Evento Antes Depois
# 0             0.9743        Chegada     0      1
# 1             1.1336        Chegada     1      2
# 2             1.9404        Chegada     2      3
# 3             1.9802          Saída     3      4
# 4             2.5780          Saída     2      3
# ..               ...            ...   ...    ...
# 115          61.1757          Saída     1      2
# 116          61.6270        Chegada     0      1
# 117          61.8587        Chegada     1      2
# 118          63.4419          Saída     2      3
# 119          63.8079          Saída     1      2
#
# [120 rows x 4 columns]
